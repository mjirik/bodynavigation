# %%
# %pylab inline

import logging
logging.basicConfig()
logger = logging.getLogger()
logger.setLevel(logging.WARNING)

import os.path as op
import sys
import matplotlib.pyplot as plt
import glob

import io3d
import sed3

#PKG_PATH = "~/projects/bodynavigation"
PKG_PATH = "~/Programming/Sources/bodynavigation"
DATA_PATH = "~/Programming/_Data/DP/3Dircadb1/1/PATIENT_DICOM"

sys.path.append(op.expanduser(PKG_PATH))
from bodynavigation.organ_detection import OrganDetection
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data3d, metadata = data3d, metadata = io3d.datareader.read(op.expanduser(DATA_PATH))
ss = OrganDetection(data3d, metadata["voxelsize_mm"])
# Out:
# WARNING:io3d.dcmreaddata:Automatic Rescale with slope 0.5
# WARNING:io3d.dcmreaddata:Problem with voxel depth. Using SliceThickness, SeriesNumber:
# WARNING:io3d.dcmreaddata:Problem with tag SeriesDescription, SeriesNumber:
# WARNING:io3d.dcmreaddata:Problem with tag ImageComments, SeriesNumber:
# Automatic Rescale with slope 0.5

# %% [markdown]
# # Aorta

# %%
seg = ss.getAorta().astype(np.uint8)
plt.figure(figsize = (15,15))
sed3.show_slices(data3d, seg*2, slice_step=20, axis=1, flipV=True)
# Out:
# /home/jirka642/bin/miniconda/envs/py27/lib/python2.7/site-packages/numpy/ma/core.py:6434: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# /home/jirka642/bin/miniconda/envs/py27/lib/python2.7/site-packages/numpy/ma/core.py:6434: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)

# %%
plt.figure(figsize = (15,15))
sed3.show_slices(data3d, seg*2, slice_step=20, axis=0, flipV=True)

# %% [markdown]
# # Vena Cava

# %%
seg = ss.getVenaCava().astype(np.uint8)
plt.figure(figsize = (15,15))
sed3.show_slices(data3d, seg*2, slice_step=20, axis=1, flipV=True)

# %%
plt.figure(figsize = (15,15))
sed3.show_slices(data3d, seg*2, slice_step=20, axis=0, flipV=True)
